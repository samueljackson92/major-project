# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pandas as pd
import mia
from mia import analysis, plotting, reduction

# %%
raw = pd.DataFrame.from_csv('../results/2015-03-05-results.csv')
raw.head()
# Out:
#       x    y      radius  avg_intensity  std_intensity  skew_intensity  \
# 0  1895  616  128.000000     256.000000     229.759436        0.545727
# 1  1639  536  128.000000     256.000000     257.700332        0.771134
# 2  1335  328  128.000000     256.000000     208.927638        0.254095
# 3  2072  648   45.254834      31.640625      37.673294        0.941469
# 4  2016  839   45.254834      31.640625      32.111435        1.017094
#
#    kurtosis_intensity             image_name   patient_id view side  class
# 0           -1.213870  p214-010-60001-cl.png  21401060001    c    l      3
# 1           -0.779772  p214-010-60001-cl.png  21401060001    c    l      3
# 2           -1.250903  p214-010-60001-cl.png  21401060001    c    l      3
# 3           -0.485973  p214-010-60001-cl.png  21401060001    c    l      3
# 4            0.059608  p214-010-60001-cl.png  21401060001    c    l      3

# %%
features = mia.reduction.reduction_feature_statistics(raw)
features.describe()
# Out:
#        blob_count  avg_radius  std_radius  min_radius  max_radius  \
# count  360.000000  360.000000  360.000000         360  360.000000
# mean   156.933333   18.624276   21.312272           8  151.570838
# std    101.082779    3.949985    7.962819           0   41.586007
# min     26.000000   11.251783    4.942047           8   32.000000
# 25%     81.000000   15.828461   15.449720           8  128.000000
# 50%    131.000000   18.024105   20.845785           8  181.019336
# 75%    198.250000   20.307923   26.569746           8  181.019336
# max    648.000000   33.661574   46.518068           8  181.019336
#
#        small_radius_count  med_radius_count  large_radius_count     density  \
# count          360.000000        360.000000          360.000000  360.000000
# mean           151.025000          3.097222            2.811111   27.203996
# std             99.448462          4.390924            1.491999    5.533270
# min             24.000000          0.000000            1.000000   18.459509
# 25%             76.750000          1.000000            2.000000   23.291710
# 50%            127.000000          2.000000            3.000000   25.825397
# 75%            189.250000          4.000000            4.000000   29.942773
# max            620.000000         37.000000            8.000000   51.209293
#
#        avg_avg_intensity  avg_std_intensity  avg_skew_intensity  \
# count         360.000000         360.000000          360.000000
# mean           13.646452          21.408362            2.149312
# std             8.183294          14.144367            0.223716
# min             2.310020           3.553002            1.535727
# 25%             7.709935          10.969145            1.986801
# 50%            11.557075          17.897254            2.138407
# 75%            17.654056          27.732207            2.291443
# max            51.369960          92.965144            3.073701
#
#        avg_kurt_intensity  std_avg_intensity  std_std_intensity  \
# count          360.000000         360.000000         360.000000
# mean             4.530314          48.577633          70.135633
# std              1.069942          27.595639          46.483148
# min              2.118016           2.702558           4.345298
# 25%              3.848934          24.798375          30.502043
# 50%              4.356317          48.859672          63.259866
# 75%              5.081154          68.743505          98.691971
# max              9.312543         132.856182         231.725405
#
#        std_skew_intensity  std_kurt_intensity    patient_id       class
# count          360.000000          360.000000  3.600000e+02  360.000000
# mean             0.639060            4.595784  2.140106e+10    2.533333
# std              0.189975            4.059613  5.295273e+02    0.958178
# min              0.380111            2.106592  2.140106e+10    1.000000
# 25%              0.532565            2.667155  2.140106e+10    2.000000
# 50%              0.599148            3.030966  2.140106e+10    3.000000
# 75%              0.669634            3.897467  2.140106e+10    3.000000
# max              1.625442           25.687622  2.140106e+10    4.000000
