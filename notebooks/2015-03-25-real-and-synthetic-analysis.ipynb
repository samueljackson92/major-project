# %%
# %matplotlib qt
import mia
import pandas as pd
import numpy as np
import re
import random
import matplotlib.pyplot as plt
from pandas.tools import plotting

# %%
batch1 = pd.DataFrame.from_csv('/Volumes/Seagate/2015-03-26/batch1_blobs.csv')
batch2 = pd.DataFrame.from_csv('/Volumes/Seagate/2015-03-26/batch2_blobs.csv')
synthetics = pd.DataFrame.from_csv('/Volumes/Seagate/2015-03-26/synthetic_blobs.csv')
synthetics.index = synthetics.img_name

hologic = pd.concat([batch1, batch2])
hologic.index = hologic.img_name
hologic.head()
# Out:
#                           x    y      radius               img_name
# img_name
# p214-010-60001-cl.png  1842  546  128.000000  p214-010-60001-cl.png
# p214-010-60001-cl.png  1482  424  128.000000  p214-010-60001-cl.png
# p214-010-60001-cl.png  1355  386  128.000000  p214-010-60001-cl.png
# p214-010-60001-cl.png  2072  658   45.254834  p214-010-60001-cl.png
# p214-010-60001-cl.png  1955  737   45.254834  p214-010-60001-cl.png

# %%
hologic_meta_path = '/Volumes/Seagate/2015-03-26/BIRADS.csv'
hologic_meta = mia.analysis.create_hologic_meta_data(hologic, hologic_meta_path)
hologic_meta.head()
# Out:
#                         patient_id side view               img_name  BIRADS  \
# img_name
# p214-010-60001-cl.png  21401060001    c    l  p214-010-60001-cl.png       3
# p214-010-60001-cl.png  21401060001    c    l  p214-010-60001-cl.png       3
# p214-010-60001-cl.png  21401060001    c    l  p214-010-60001-cl.png       3
# p214-010-60001-cl.png  21401060001    c    l  p214-010-60001-cl.png       3
# p214-010-60001-cl.png  21401060001    c    l  p214-010-60001-cl.png       3
#
#                        img_number
# img_name
# p214-010-60001-cl.png           1
# p214-010-60001-cl.png           1
# p214-010-60001-cl.png           1
# p214-010-60001-cl.png           1
# p214-010-60001-cl.png           1

# %%
synthetic_meta_path = '/Volumes/Seagate/2015-03-26/synthetic_meta_data_cleaned.csv'
synthetic_meta = mia.analysis.create_synthetic_meta_data(synthetics, synthetic_meta_path)
synthetic_meta.head()
# Out:
#                          Vol  CmprTh  SkTh  LigThCrs  LigThFn  #cmprts  \
# img_name
# test_Mix_DPerc0_c_0.dcm  436       5   0.5       400      200      333
# test_Mix_DPerc0_c_0.dcm  436       5   0.5       400      200      333
# test_Mix_DPerc0_c_0.dcm  436       5   0.5       400      200      333
# test_Mix_DPerc0_c_0.dcm  436       5   0.5       400      200      333
# test_Mix_DPerc0_c_0.dcm  436       5   0.5       400      200      333
#
#                          #cmprts.1  Dperc  VBD  VBD.1 BIRADS  min_speed  \
# img_name
# test_Mix_DPerc0_c_0.dcm       1000      0   24     21      1        0.5
# test_Mix_DPerc0_c_0.dcm       1000      0   24     21      1        0.5
# test_Mix_DPerc0_c_0.dcm       1000      0   24     21      1        0.5
# test_Mix_DPerc0_c_0.dcm       1000      0   24     21      1        0.5
# test_Mix_DPerc0_c_0.dcm       1000      0   24     21      1        0.5
#
#                          max_speed  min_ratio  max_ratio       phantom_name
# img_name
# test_Mix_DPerc0_c_0.dcm          2        0.5          2  test_Mix_DPerc0_c
# test_Mix_DPerc0_c_0.dcm          2        0.5          2  test_Mix_DPerc0_c
# test_Mix_DPerc0_c_0.dcm          2        0.5          2  test_Mix_DPerc0_c
# test_Mix_DPerc0_c_0.dcm          2        0.5          2  test_Mix_DPerc0_c
# test_Mix_DPerc0_c_0.dcm          2        0.5          2  test_Mix_DPerc0_c

# %%
synth_class_labels = synthetic_meta['BIRADS']
hologic_class_labels = hologic_meta['BIRADS']
class_labels = pd.concat([hologic_class_labels, synth_class_labels])

#replace BIRADS inspecific BIRADS classes
class_labels.replace('3 or 4', 4, inplace=True)
class_labels.replace(re.compile(r'2 \([a-z]+\)'), 2, inplace=True)
class_labels = class_labels.astype(float)

# %% [markdown]
# Compute shape based features from raw blob detections

# %%
hologic_blob_features = mia.analysis.features_from_blobs(hologic)
hologic_blob_features.describe()
# Out:
#        blob_count  avg_radius  std_radius  min_radius  max_radius  \
# count  360.000000  360.000000  360.000000         360  360.000000
# mean   251.777778   17.679679   20.295388           8  154.272791
# std    182.143063    3.290097    7.305919           0   40.349384
# min     26.000000   11.633776    5.269543           8   45.254834
# 25%    113.000000   15.375540   14.601573           8  128.000000
# 50%    203.500000   17.154971   20.158492           8  181.019336
# 75%    328.250000   19.297899   25.607779           8  181.019336
# max    978.000000   34.201332   45.057882           8  181.019336
#
#        small_radius_count  med_radius_count  large_radius_count     density  \
# count          360.000000        360.000000          360.000000  360.000000
# mean           243.975000          3.927778            3.875000   42.546985
# std            179.730972          5.394241            2.559256    6.866999
# min             22.000000          0.000000            1.000000   32.678451
# 25%            109.000000          1.000000            2.000000   37.506466
# 50%            196.000000          3.000000            3.000000   41.412974
# 75%            314.000000          4.000000            5.000000   46.069529
# max            958.000000         44.000000           14.000000   79.518497
#
#        lower_radius_qt  upper_radius_qt  upper_dist_count
# count       360.000000       360.000000        360.000000
# mean          8.050626        17.575128         66.580556
# std           0.392667         3.161404         57.047643
# min           8.000000        11.313708          5.000000
# 25%           8.000000        16.000000         27.000000
# 50%           8.000000        16.000000         49.000000
# 75%           8.000000        16.000000         83.000000
# max          11.313708        32.000000        337.000000

# %%
synthetic_blob_features = mia.analysis.features_from_blobs(synthetics)
synthetic_blob_features.describe()
# Out:
#        blob_count  avg_radius  std_radius  min_radius  max_radius  \
# count   60.000000   60.000000   60.000000          60   60.000000
# mean    80.733333   21.982949   24.371230           8  130.588167
# std     15.154422    2.342589    2.647525           0   26.605668
# min     40.000000   18.645281   19.316414           8   90.509668
# 25%     72.750000   20.293316   22.697181           8  128.000000
# 50%     84.500000   21.347224   23.683670           8  128.000000
# 75%     92.000000   23.621765   26.496192           8  128.000000
# max    109.000000   28.319596   31.413381           8  181.019336
#
#        small_radius_count  med_radius_count  large_radius_count    density  \
# count           60.000000         60.000000           60.000000  60.000000
# mean            74.033333          1.666667            5.033333  35.482570
# std             15.483142          1.445820            2.863959   4.033106
# min             33.000000          0.000000            2.000000  29.205906
# 25%             66.000000          1.000000            3.750000  33.215826
# 50%             78.000000          1.000000            4.000000  34.529411
# 75%             84.250000          2.250000            5.000000  37.044697
# max            103.000000          6.000000           13.000000  53.889814
#
#        lower_radius_qt  upper_radius_qt  upper_dist_count
# count        60.000000        60.000000         60.000000
# mean          8.358985        22.714521         22.316667
# std           1.004434         4.996060          6.474177
# min           8.000000        16.000000          8.000000
# 25%           8.000000        22.627417         19.000000
# 50%           8.000000        22.627417         22.000000
# 75%           8.000000        22.627417         28.000000
# max          11.313708        35.313708         33.000000

# %% [markdown]
# Select a subset of synthetics to be used. This takes a random sample from each group DPerc*.

# %%
syn_feature_meta = mia.analysis.remove_duplicate_index(synthetic_meta)

# synthetic_blob_features['phantom_name'] = syn_feature_meta.phantom_name.tolist()
synthetic_blob_features.head()

random_synthetic_features = synthetic_blob_features
# group = synthetic_blob_features.groupby('phantom_name')

# def select_random(x):
#     return x.ix[random.sample(x.index, 1)]
# random_synthetic_features = group.apply(select_random)

# random_synthetic_features.drop('phantom_name', axis=1, inplace=True)
# random_synthetic_features.reset_index(drop=True, level=0, inplace=True)
# random_synthetic_features

# %% [markdown]
# Join datasets. Results will include both hologic and synthetic images

# %%
blob_features = pd.concat([hologic_blob_features, random_synthetic_features])
blob_features.describe()
# Out:
#        blob_count  avg_radius  std_radius  min_radius  max_radius  \
# count  420.000000  420.000000  420.000000         420  420.000000
# mean   227.342857   18.294432   20.877651           8  150.889274
# std    179.021289    3.510032    6.982771           0   39.540662
# min     26.000000   11.633776    5.269543           8   45.254834
# 25%     95.000000   15.665675   15.788996           8  128.000000
# 50%    173.000000   17.815042   21.195257           8  181.019336
# 75%    302.500000   20.392035   25.700622           8  181.019336
# max    978.000000   34.201332   45.057882           8  181.019336
#
#        small_radius_count  med_radius_count  large_radius_count     density  \
# count          420.000000        420.000000          420.000000  420.000000
# mean           219.697619          3.604762            4.040476   41.537783
# std            176.793683          5.084581            2.632780    6.987061
# min             22.000000          0.000000            1.000000   29.205906
# 25%             89.000000          1.000000            2.000000   36.334336
# 50%            167.000000          2.000000            3.000000   40.292799
# 75%            294.250000          4.000000            5.000000   45.100630
# max            958.000000         44.000000           14.000000   79.518497
#
#        lower_radius_qt  upper_radius_qt  upper_dist_count
# count       420.000000       420.000000        420.000000
# mean          8.094677        18.309327         60.257143
# std           0.534642         3.914081         55.088955
# min           8.000000        11.313708          5.000000
# 25%           8.000000        16.000000         24.000000
# 50%           8.000000        16.000000         39.000000
# 75%           8.000000        22.627417         75.250000
# max          11.313708        35.313708        337.000000

# %% [markdown]
# Filter the columns that we want to run with

# %%
# columns = filter(lambda c: c not in ['min_radius', 'density', 'lower_radius_qt', 'upper_radius_qt', 'upper_dist_count', 'small_radius_count', 'med_radius_count', 'large_radius_count', 'lower_radius_qt'], blob_features.columns)
selected_features = blob_features

# %% [markdown]
# Run t-SNE on features to obtain mapping

# %%
mapping = mia.analysis.tSNE(selected_features, perplexity=45, learning_rate=400, verbose=2)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 420 / 420
# [t-SNE] Mean sigma: 1.121329
# [t-SNE] Iteration 10: error = 15.2206589, gradient norm = 0.1464931
# [t-SNE] Iteration 20: error = 12.6857604, gradient norm = 0.1402406
# [t-SNE] Iteration 30: error = 12.4894061, gradient norm = 0.1294939
# [t-SNE] Iteration 40: error = 12.8387100, gradient norm = 0.1189716
# [t-SNE] Iteration 50: error = 12.4290254, gradient norm = 0.1190262
# [t-SNE] Iteration 60: error = 12.0285452, gradient norm = 0.1325424
# [t-SNE] Iteration 70: error = 12.6350985, gradient norm = 0.1303535
# [t-SNE] Iteration 80: error = 12.3735981, gradient norm = 0.1239572
# [t-SNE] Iteration 83: did not make any progress during the last 30 episodes. Finished.
# [t-SNE] Error after 83 iterations with early exaggeration: 12.863478
# [t-SNE] Iteration 90: error = 0.6911080, gradient norm = 0.0210723
# [t-SNE] Iteration 100: error = 0.3773800, gradient norm = 0.0084136
# [t-SNE] Iteration 110: error = 0.3432450, gradient norm = 0.0026968
# [t-SNE] Iteration 120: error = 0.3380230, gradient norm = 0.0009156
# [t-SNE] Iteration 130: error = 0.3362972, gradient norm = 0.0004081
# [t-SNE] Iteration 140: error = 0.3354656, gradient norm = 0.0003133
# [t-SNE] Iteration 150: error = 0.3350224, gradient norm = 0.0002935
# [t-SNE] Iteration 160: error = 0.3347771, gradient norm = 0.0002853
# [t-SNE] Iteration 170: error = 0.3346375, gradient norm = 0.0002808
# [t-SNE] Iteration 180: error = 0.3345564, gradient norm = 0.0002783
# [t-SNE] Iteration 190: error = 0.3345087, gradient norm = 0.0002768
# [t-SNE] Iteration 200: error = 0.3344804, gradient norm = 0.0002759
# [t-SNE] Iteration 210: error = 0.3344636, gradient norm = 0.0002754
# [t-SNE] Iteration 220: error = 0.3344536, gradient norm = 0.0002751
# [t-SNE] Iteration 230: error = 0.3344476, gradient norm = 0.0002749
# [t-SNE] Iteration 240: error = 0.3344440, gradient norm = 0.0002748
# [t-SNE] Iteration 250: error = 0.3344419, gradient norm = 0.0002747
# [t-SNE] Iteration 260: error = 0.3344406, gradient norm = 0.0002746
# [t-SNE] Iteration 261: error difference 0.000000. Finished.
# [t-SNE] Error after 261 iterations: 0.334441

# %%
labels = mia.analysis.remove_duplicate_index(class_labels)
mapping['BIRADS'] = labels['BIRADS']

hol_map = mapping[:-60]
hol_map.shape

syn_map = mapping[-60:]
syn_map.head()

ax = mia.plotting.plot_scatter_2d(hol_map, [0,1], 'BIRADS')
ax = mia.plotting.plot_scatter_2d(syn_map, [0,1], 'BIRADS', ax=ax, marker='^', s=50)

plt.show()

# %%
mia.analysis.measure_closeness(mapping, labels['BIRADS'])
# Out:
# 3    9.620367
# 4    9.108296
# 1    8.869278
# 2    8.567595
# dtype: float64

# %%
mia.plotting.plot_scatter_2d(syn_map, [0,1], 'BIRADS', marker='^', s=50, annotate=True)
plt.show()

# %%
syn_feature_meta.loc[random_synthetic_features.index]
# Out:
#                           Vol  CmprTh  SkTh  LigThCrs  LigThFn  #cmprts  \
# img_name
# test_Mix_DPerc0_c_8.dcm   436       5   0.5       400      200      333
# test_Mix_DPerc10_c_4.dcm  436       5   1.5       600      200      333
# test_Mix_DPerc20_c_4.dcm  436       5   1.5       600      200      333
# test_Mix_DPerc35_c_7.dcm  436       5   1.5       600      200      333
# test_Mix_DPerc5_c_6.dcm   436       5   1.5       600      200      333
# test_Mix_DPerc75_c_8.dcm  436       5   1.5       600      200      333
#
#                           #cmprts.1  Dperc  VBD  VBD.1   BIRADS  min_speed  \
# img_name
# test_Mix_DPerc0_c_8.dcm        1000      0   24     21        1        0.5
# test_Mix_DPerc10_c_4.dcm       2000     10   40     33  2 (med)        0.5
# test_Mix_DPerc20_c_4.dcm       2000     20   46     38   2 (hi)        0.5
# test_Mix_DPerc35_c_7.dcm       2000     35   55     47        3        0.5
# test_Mix_DPerc5_c_6.dcm        1000      5   35     27  2 (low)        0.5
# test_Mix_DPerc75_c_8.dcm       2000     75   67     59   3 or 4        0.5
#
#                           max_speed  min_ratio  max_ratio        phantom_name
# img_name
# test_Mix_DPerc0_c_8.dcm           2        0.5          2   test_Mix_DPerc0_c
# test_Mix_DPerc10_c_4.dcm          2        0.5          2  test_Mix_DPerc10_c
# test_Mix_DPerc20_c_4.dcm          2        0.5          2  test_Mix_DPerc20_c
# test_Mix_DPerc35_c_7.dcm          2        0.5          2  test_Mix_DPerc35_c
# test_Mix_DPerc5_c_6.dcm           2        0.5          2   test_Mix_DPerc5_c
# test_Mix_DPerc75_c_8.dcm          2        0.5          2  test_Mix_DPerc75_c

# %%
mapping.to_csv('/Volumes/Seagate/2015-03-26/mapping-with-both.csv')

# %% [markdown]
# Compare synthetics with the hologic dataset by class.

# %%
birads_class = labels['BIRADS'] == 1
syn_class = random_synthetic_features[birads_class]
hol_class = hologic_blob_features[birads_class]
syn_class.describe() - hol_class.describe()
# Out:
#        blob_count  avg_radius  std_radius  min_radius  max_radius  \
# count  -55.000000  -55.000000  -55.000000         -55  -55.000000
# mean  -250.910714    4.140017   -1.500180           0  -73.988703
# std           NaN         NaN         NaN         NaN         NaN
# min    -12.000000    8.926640   14.314276           0   45.254834
# 25%   -177.000000    5.674894    2.590794           0  -90.509668
# 50%   -213.000000    3.835439   -3.715167           0  -90.509668
# 75%   -318.750000    2.693215   -6.282151           0  -90.509668
# max   -764.000000   -2.266647  -13.490180           0  -90.509668
#
#        small_radius_count  med_radius_count  large_radius_count    density  \
# count          -55.000000           -55.000          -55.000000 -55.000000
# mean          -250.678571            -2.125            1.892857  -3.908121
# std                   NaN               NaN                 NaN        NaN
# min            -16.000000             2.000            7.000000   2.839540
# 25%           -172.500000             0.000            4.000000  -0.201768
# 50%           -214.500000            -1.000            2.000000  -2.639060
# 75%           -321.000000            -2.000            0.000000  -6.875456
# max           -764.000000           -30.000           -6.000000 -20.648015
#
#        lower_radius_qt  upper_radius_qt  upper_dist_count
# count              -55       -55.000000        -55.000000
# mean                 0         6.385647        -49.017857
# std                NaN              NaN               NaN
# min                  0        11.313708          8.000000
# 25%                  0         6.627417        -21.750000
# 50%                  0         6.627417        -36.500000
# 75%                  0         6.627417        -51.500000
# max                  0         0.000000       -246.000000

# %% [markdown]
# ## Higher dimensional plot
# Can show the which are the largest contributing features in the dataset.

# %%
blob_norm = mia.analysis.normalize_data_frame(blob_features)
blob_norm.columns = blob_features.columns.values
blob_norm['BIRADS'] = labels

columns = filter(lambda c: c not in ['min_radius'], blob_norm.columns)
plotting.parallel_coordinates(blob_norm[columns], 'BIRADS')
plt.show()
